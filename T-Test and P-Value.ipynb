# %%
import random
a = [ random.gauss(50,20) for x in range(30)]
b = [ random.gauss(55,15) for x in range(30)]

# %%
import seaborn as sns
sns.set_style('darkgrid')
sns.kdeplot(a,shade = True)
sns.kdeplot(b,shade = True)
# Out:
# C:\Users\VIZECH\AppData\Local\Temp\ipykernel_2712\1795038356.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(a,shade = True)
# C:\Users\VIZECH\AppData\Local\Temp\ipykernel_2712\1795038356.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(b,shade = True)
# <Axes: ylabel='Density'>

# %%
import scipy.stats as stats

# %%
t_stat,p_value = stats.ttest_ind(a,b,equal_var=False)

# %%
t_stat,p_value
# Out:
# (-0.8581229805019259, 0.3944919810238414)

# %%
import numpy as np

# %%
np.mean(a), np.mean(b)
# Out:
# (51.657380798560354, 54.613908247143975)

# %%
import random
a = [ random.gauss(50,20) for x in range(30)]
b = [ random.gauss(60,25) for x in range(30)]

# %%
t_stat,p_value = stats.ttest_rel(a,b)

# %%
t_stat,p_value
# Out:
# (-0.03592440776356964, 0.9715887804405672)

# %%
np.mean(b) - np.mean(a)
# Out:
# 0.2041102343694945

# %%
np.mean(a)
# Out:
# 55.210960711671625

# %%
t_stat,p_value = stats.ttest_1samp(a,40,axis = 0)

# %%
t_stat,p_value
# Out:
# (4.02299937443896, 0.0003758292252729411)

# %%
t_stat, p_value = stats.ttest_1samp(a, 100)

# %%
t_stat,p_value
# Out:
# (-11.845818318392416, 1.239692206299625e-12)
