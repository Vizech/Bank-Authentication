# %%
from scipy.stats import binom
import matplotlib.pyplot as plt

# %%
n = 6
p = 0.6

# %%
r_values = list(range(n+1))

# %%
mean, var = binom.stats(n, p)

# %%
dist = [binom.pmf(r, n, p) for r in r_values ]

# %%
print("r\tp(r)")
for i in range(n + 1):
    print(str(r_values[i]) + "\t" + str(dist[i]))
# Out:
# r	p(r)
# 0	0.004096000000000003
# 1	0.03686400000000002
# 2	0.1382400000000001
# 3	0.2764800000000001
# 4	0.3110400000000001
# 5	0.1866240000000001
# 6	0.04665599999999999

# %%
plt.bar(r_values, dist)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters
n = 6
p = 0.6

# Define the range of x values
r_values = list(range(n + 1))

# Compute the PMF for each r_value
dist = [binom.pmf(r, n, p) for r in r_values]

# Create the bar plot
plt.bar(r_values, dist, color='blue', alpha=0.7)

# Add labels and title
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title('Binomial Distribution PMF (n=6, p=0.6)')
plt.grid(axis='y')

# Show the plot
plt.show()
