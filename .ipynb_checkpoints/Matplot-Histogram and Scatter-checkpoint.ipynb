# %%
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt

# Load the dataset
california_housing_data = fetch_california_housing()

# Define X and Y for the scatter plot
X_axis = california_housing_data.data[:, 0]  # Median Income (MedInc)
Y_axis = california_housing_data.target

# %%
# Apply the 'ggplot' style for the plot
style.use('ggplot')

# Create the figure for the histogram
plt.figure(figsize=(12, 5))

# Plot the histogram for House Prices
plt.hist(Y_axis, bins=50, color='orange', edgecolor='black')

# Set the labels for the histogram
plt.xlabel('House Prices')
plt.ylabel('Frequency')
plt.title('Histogram: Distribution of House Prices')

# Display the plot
plt.show()

# %%
# Apply the 'ggplot' style for the plot
style.use('ggplot')

# Create the figure for the scatter plot with a size of (7, 7)
plt.figure(figsize=(7, 7))

# Plot the scatter plot for Median Income vs House Prices
plt.scatter(X_axis, Y_axis, color='blue')

# Set the labels and title for the scatter plot
plt.xlabel('Median Income (X-axis)')
plt.ylabel('House Prices (Y-axis)')
plt.title('Scatter Plot: Median Income vs. House Prices')

# Display the plot
plt.show()
